# %%
import contextlib
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords, wordnet
import mmh3
import numpy as np
import contextlib
import numpy as np
import string
import nltk
import json

import spacy
import lemminflect
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser'])
POS = ("CC", "CD", "DT", "EX", "FW", "IN", "JJ", "JJR", "JJS", "LS", "MD", "NN", "NNP", "NNPS", "NNS", "PDT", "PRP", "PRP$", "RB", "RBR", "RBS", "RP", "VB", "VBD", "VBG", "VBN", "VBP", "VBZ", "WDT", "WP", "WP$", "WRB")

def lemmatize(word): # Takes a word and uses the spacy lemmatizer to return the lemmatized form
    token = nlp(str(word))[0]
    lemma = token.lemma_
    inflections = {token._.inflect(pos) for pos in POS} # returns the inflection of the lemmatized token. (ex: run -> {'ran', 'run', 'runner', 'runnest', 'running', 'runs'} )
    return lemma, inflections

def tokenize(sentence): # Tokenizes a sentence and lemmatizes the words within
    tokenized = nlp(sentence.translate(str.maketrans('', '', string.punctuation)))
    return [token.lemma_ for token in tokenized if token.lemma_.lower() not in en_stopwords and wordnet.synsets(token.lemma_)] # disregards lemmatized token if it's in list of stopwords or not in english dictionary (wordnet)

nltk.download('stopwords')
nltk.download('wordnet')
en_stopwords = set(stopwords.words('english'))

data = [] # loads the datasets as binaries 
for i in range (1, 1731):
    with contextlib.suppress(FileNotFoundError):
        with open(f'data/fairy_tales/{i}.txt', 'r', encoding='ISO-8859-1') as f:
            data.append(f.read())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Yourui/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Yourui/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data[0]
# Out:
# 'THE LONG WAPPERS, AND THEIR TRICKS\n\n\nIn his rambles in Belgium, the story-teller found no parts of any city\nin the land equal in interest to those of old Antwerp. If he sauntered\ndown toward evening, into the narrow streets and through the stone\ngateway, blackened with age, under which the great Charles V. rode, the\nfairies and funny folks seemed almost as near to him as the figures in\nreal history. Here, many a prince or princess made their â\x80\x9cjoyous\nentry,â\x80\x9d into the wonderful city of Brabo, the boy hero, who slew the\ncruel giant Antigonus and cut off his cruel hands.\n\nHere, the story-teller noticed a great many images of the Virgin Mary;\nwhereas, in the newer parts of the city, there were few or none. They\nwere usually set in the house corners, where two streets came together.\nInquiring into the reason of this, he discovered a new kind of Belgian\nfairy, the Wapper, famous for his long legs and funny tricks. Here were\nfairies on stilts.\n\nThis mischievous fellow was very active in old times. He could be as\nlong, or as short, as it pleased him. He could stretch his body out,\nand up to the house roofs, or shrink it down, as if it were made of\nIndia rubber, according to his whim. For example, he would sit on a\nbridge, and lengthen his legs out until they were as thin as those of a\nmosquito. Again, he could drink until his body bulged out like a plum\npudding, or a bag of oats. He was very fond of milk, and would suck or\nswallow it, until he looked the way a mosquito does, that has bored a\nhole through a fat boyâ\x80\x99s skin, and filled himself so red and round,\nthat you would think he might burst.\n\nIn days, centuries ago, the Long Wappers, as they were sometimes\ncalled, used to go around the streets of old Antwerp at dusk. Or, in\nthe dark night, they would wait in lonely places and run off with the\npeople. No one ever heard of any good boys or girls being snatched\naway, but drunken louts, coming home very late, that is toward\nmidnight, from the dram shops, were often caught. The Wappers would\nseize them by the hair, swing them round, and then toss them into the\ngutters, till they were black with mud; or, they would throw them into\nthe Scheldt River. Occasionally a toper would be found in a hog pen,\nsleeping with the sow and her piggies. When the man woke up, about\nnoon, he could not tell how he ever got there; but the Wappers knew,\nand they kept their secret.\n\nHow numerous the Wappers were, the story-teller never could find out.\nIt was in their power, to be as wee as a baby, or as big as a giant.\nThat was the peculiar thing about them. It was very funny, that this\nkind of fairies never weighed more or less. No matter how much they\ndrank of milk, they were never any heavier, or lighter, for it. And to\ntheir length, or shortness, they were more like earthworms that, in\ncrawling, can be long, or short, as they please.\n\nSometimes the Wappers rose up out of the water, or sat on the bridges\nwith their feet cooling in the stream. In that position, from their\ntoes, up to their bodies, their legs looked more like black threads, or\nwires; or, as if a strand from a spiderâ\x80\x99s web had broken loose. If the\nwater was not very deep, then they seemed to be on stilts.\n\nOne particular stream of water was named the Wapperâ\x80\x99s Rui, or Wapperâ\x80\x99s\nCreek, and the bridge crossing it was called the Wapperâ\x80\x99s Bruck. While\nthe Wapper was wading in the water, he seemed to be as long as a\nlightning rod, but as soon as the creature reached the bank, to step\nout, on land, his legs shortened to the size of a boyâ\x80\x99s.\n\nWhen on the bridge, he pulled up his wiry limbs, and looked like any\nhuman youngster. When he made use, to the utmost, of this elastic power\nof lengthening or shortening himself, the mischievous rascal elongated\nhimself until his legs were like stilts, so that he could look down\ninto the church windows. Then he would howl at the priest ...

# %%
def hash_token(token, bits):
    representation = np.zeros(bits)
    
    for i in range(3):
        digest = mmh3.hash(token, i) % bits
        representation[digest] = 1
    return representation

# %%
with open('data/fairytales_iterative_vectors.json', 'r') as f:
    iterative_vectors = json.load(f)
with open('data/fairytales_word_tf-idfs.json', 'r') as f:
    tf_idfs = json.load(f)
with open('data/fairytales_word_bloom-filters.json', 'r') as f:
    bloom_filters = json.load(f)
with open('data/fairytales_tokenized.json', 'r') as f:
    tokenized_corpus = json.load(f)

# %%
def generate_vector(word, tokenized_sentence, bits, deltas):
    indices = [i for i, x in enumerate(tokenized_sentence) if x == word]
    instance_representation = np.zeros(bits)
    adjacent_words = 0
    
    for index in indices:
        for delta in deltas:
            if index + delta < 0:
                continue
            with contextlib.suppress(IndexError):
                adjacent_word = tokenized_sentence[index + delta]
                try:
                    tf_idf = tf_idfs[word][adjacent_word]
                except KeyError:
                    tf_idf = 0
                try:
                    instance_representation += np.array(iterative_vectors[adjacent_word]) * tf_idf
                except:
                    instance_representation += np.array(bloom_filters[adjacent_word]) * tf_idf 
                    # generate new bloom filter to represent word if vector is not found
                adjacent_words += 1
    return instance_representation, adjacent_words

# %%
def extract_vectors(word, deltas=None, bits=32):
    if deltas is None:
        deltas = [-4, -3, -2, -1, 1, 2, 3, 4]

    total_adjacent_words = 0
    representations = np.zeros(bits)

    for sentence in tokenized_corpus:
        if word in sentence:
            representation, adjacent_words = generate_vector(word, sentence, bits, deltas)
            representations += representation
            total_adjacent_words += adjacent_words
    iterative_vectors[word] = representations
    return representations / float(total_adjacent_words)

# %%
# keep only the most frequently occurring words next to the target word (ex: 1000+ occurrences) + aggregate those words + collect data
    # Table 1: Most frequent words
    # Table 2: Most frequent words with count vectors
# test discarding bits with high variance values

# %%
def store_encoding(word, fname, args):
    vector = list(extract_vectors(word, **args))
    
    with open(fname, 'r') as f:
        iterative_vectors = json.load(f)
    iterative_vectors[word] = vector
    with open(fname, 'w') as f:
        json.dump(iterative_vectors, f, indent=4)

# %%
ITERATIONS = 50
for i in range(ITERATIONS): 
    for word in tf_idfs.keys():
        print(f"iteration {i}, \"{word}\"")
        store_encoding(word, 'data/fairytales_iterative_vectors.json', {'deltas': [-4, -3, -2, -1, 1, 2, 3, 4], 'bits':32})
# Out:
# iteration 0
# "long", total_adjacent_words: 32899
# "trick", total_adjacent_words: 1582
# "ramble", total_adjacent_words: 158
# "belgium", total_adjacent_words: 316
# "storyteller", total_adjacent_words: 413
# "find", total_adjacent_words: 36273
# "part", total_adjacent_words: 6303
# "city", total_adjacent_words: 5898
# "land", total_adjacent_words: 10908
# "equal", total_adjacent_words: 819
# "interest", total_adjacent_words: 512
# "old", total_adjacent_words: 46379
# "antwerp", total_adjacent_words: 95
# "saunter", total_adjacent_words: 77
# "evening", total_adjacent_words: 6756
# "narrow", total_adjacent_words: 739
# "street", total_adjacent_words: 2018
# "stone", total_adjacent_words: 10053
# "gateway", total_adjacent_words: 211
# "blacken", total_adjacent_words: 74
# "age", total_adjacent_words: 2820
# "great", total_adjacent_words: 37786
# "charles", total_adjacent_words: 107
# "v", total_adjacent_words: 189
# "ride", total_adjacent_words: 8998
# "fairy", total_adjacent_words: 12710
# "funny", total_adjacent_words: 468
# "folk", total_adjacent_words: 2823
# "seem", total_adjacent_words: 11247
# "almost", total_adjacent_words: 3636
# "near", total_adjacent_words: 10905
# "figure", total_adjacent_words: 1811
# "real", total_adjacent_words: 1599
# "history", total_adjacent_words: 739
# "many", total_adjacent_words: 15229
# "prince", total_adjacent_words: 31938
# "princess", total_adjacent_words: 27443
# "make", total_adjacent_words: 49078
# "wonderful", total_adjacent_words: 4378
# "boy", total_adjacent_words: 12407
# "hero", total_adjacent_words: 3008
# "slay", total_adjacent_words: 2068
# "cruel", total_adjacent_words: 2172
# "giant", total_adjacent_words: 10902
# "antigonus", total_adjacent_words: 39
# "cut", total_adjacent_words: 7434
# "hand", total_adjacent_words: 25520
# "notice", total_adjacent_words: 3702
# "image", total_adjacent_words: 978
# "virgin", total_adjacent_words: 227
# "mary", total_adjacent_words: 380
# "new", total_adjacent_words: 6433
# "none", total_adjacent_words: 3788
# "usually", total_adjacent_words: 665
# "set", total_adjacent_words: 16587
# "house", total_adjacent_words: 18563
# "corner", total_adjacent_words: 3112
# "two", total_adjacent_words: 24735
# "come", total_adjacent_words: 85080
# "together", total_adjacent_words: 10592
# "inquire", total_adjacent_words: 1573
# "reason", total_adjacent_words: 2274
# "discover", total_adjacent_words: 2668
# "kind", total_adjacent_words: 6027
# "belgian", total_adjacent_words: 501
# "famous", total_adjacent_words: 948
# "leg", total_adjacent_words: 4177
# "stilt", total_adjacent_words: 27
# "mischievous", total_adjacent_words: 244
# "fellow", total_adjacent_words: 4256
# "active", total_adjacent_words: 189
# "time", total_adjacent_words: 41885
# "short", total_adjacent_words: 3315
# "please", total_adjacent_words: 3527
# "stretch", total_adjacent_words: 2671
# "body", total_adjacent_words: 5843
# "roof", total_adjacent_words: 2303
# "shrink", total_adjacent_words: 406
# "india", total_adjacent_words: 139
# "rubber", total_adjacent_words: 28
# "accord", total_adjacent_words: 1612
# "whim", total_adjacent_words: 48
# "example", total_adjacent_words: 448
# "sit", total_adjacent_words: 19610
# "bridge", total_adjacent_words: 2804
# "lengthen", total_adjacent_words: 195
# "thin", total_adjacent_words: 1307
# "mosquito", total_adjacent_words: 57
# "drink", total_adjacent_words: 7707
# "bulge", total_adjacent_words: 61
# "like", total_adjacent_words: 30256
# "plum", total_adjacent_words: 280
# "pudding", total_adjacent_words: 186
# "bag", total_adjacent_words: 2827
# "oat", total_adjacent_words: 254
# "fond", total_adjacent_words: 1330
# "milk", total_adjacent_words: 3078
# "suck", total_adjacent_words: 349
# "swallow", total_adjacent_words: 1763
# "look", total_adjacent_words: 33116
# "way", total_adjacent_words: 21662
# "bore", total_adjacent_words: 291
# "hole", total_adjacent_words: 2936
# "fat", total_adjacent_words: 1857
# "skin", total_adjacent_words: 3369
# "fill", total_adjacent_words: 5966
# "red", total_adjacent_words: 7485
# "round", total_adjacent_words: 12445
# "think", total_adjacent_words: 27999
# "might", total_adjacent_words: 16222
# "burst", total_adjacent_words: 2212
# "day", total_adjacent_words: 42823
# "century", total_adjacent_words: 479
# "ago", total_adjacent_words: 2496
# "sometimes", total_adjacent_words: 2640
# "call", total_adjacent_words: 17683
# "used", total_adjacent_words: 30
# "go", total_adjacent_words: 95286
# "around", total_adjacent_words: 6043
# "dusk", total_adjacent_words: 310
# "dark", total_adjacent_words: 5388
# "night", total_adjacent_words: 19615
# "wait", total_adjacent_words: 8867
# "lonely", total_adjacent_words: 1583
# "place", total_adjacent_words: 19505
# "run", total_adjacent_words: 17559
# "people", total_adjacent_words: 14995
# "one", total_adjacent_words: 79388
# "ever", total_adjacent_words: 13140
# "hear", total_adjacent_words: 25551
# "good", total_adjacent_words: 28615
# "girl", total_adjacent_words: 16064
# "snatch", total_adjacent_words: 855
# "away", total_adjacent_words: 27609
# "drunken", total_adjacent_words: 77
# "lout", total_adjacent_words: 62
# "home", total_adjacent_words: 21568
# "late", total_adjacent_words: 1952
# "midnight", total_adjacent_words: 1518
# "dram", total_adjacent_words: 49
# "shop", total_adjacent_words: 1190
# "often", total_adjacent_words: 4482
# "catch", total_adjacent_words: 8192
# "seize", total_adjacent_words: 5176
# "hair", total_adjacent_words: 7606
# "swing", total_adjacent_words: 1136
# "toss", total_adjacent_words: 1096
# "gutter", total_adjacent_words: 124
# "till", total_adjacent_words: 17497
# "black", total_adjacent_words: 8853
# "mud", total_adjacent_words: 642
# "throw", total_adjacent_words: 11186
# "scheldt", total_adjacent_words: 41
# "river", total_adjacent_words: 7005
# "occasionally", total_adjacent_words: 141
# "toper", total_adjacent_words: 5
# "hog", total_adjacent_words: 137
# "pen", total_adjacent_words: 242
# "sleep", total_adjacent_words: 10123
# "sow", total_adjacent_words: 594
# "piggy", total_adjacent_words: 99
# "man", total_adjacent_words: 56616
# "wake", total_adjacent_words: 2860
# "noon", total_adjacent_words: 620
# "tell", total_adjacent_words: 37453
# "get", total_adjacent_words: 35582
# "know", total_adjacent_words: 34821
# "keep", total_adjacent_words: 13649
# "secret", total_adjacent_words: 2693
# "numerous", total_adjacent_words: 571
# "never", total_adjacent_words: 22522
# "power", total_adjacent_words: 5434
# "wee", total_adjacent_words: 757
# "baby", total_adjacent_words: 3053
# "big", total_adjacent_words: 8312
# "peculiar", total_adjacent_words: 204
# "thing", total_adjacent_words: 16814
# "weigh", total_adjacent_words: 429
# "less", total_adjacent_words: 2095
# "matter", total_adjacent_words: 4553
# "much", total_adjacent_words: 19150
# "heavy", total_adjacent_words: 3153
# "light", total_adjacent_words: 8873
# "length", total_adjacent_words: 3414
# "shortness", total_adjacent_words: 11
# "earthworm", total_adjacent_words: 82
# "crawling", total_adjacent_words: 7
# "rise", total_adjacent_words: 8828
# "water", total_adjacent_words: 18945
# "foot", total_adjacent_words: 12390
# "cool", total_adjacent_words: 1080
# "stream", total_adjacent_words: 3292
# "position", total_adjacent_words: 552
# "toe", total_adjacent_words: 634
# "thread", total_adjacent_words: 1496
# "wire", total_adjacent_words: 143
# "strand", total_adjacent_words: 310
# "web", total_adjacent_words: 323
# "break", total_adjacent_words: 7804
# "loose", total_adjacent_words: 1207
# "deep", total_adjacent_words: 4448
# "particular", total_adjacent_words: 526
# "name", total_adjacent_words: 9921
# "creek", total_adjacent_words: 48
# "cross", total_adjacent_words: 3837
# "wade", total_adjacent_words: 346
# "lightning", total_adjacent_words: 1052
# "rod", total_adjacent_words: 1014
# "soon", total_adjacent_words: 19226
# "creature", total_adjacent_words: 5354
# "reach", total_adjacent_words: 10834
# "bank", total_adjacent_words: 2433
# "step", total_adjacent_words: 5637
# "shorten", total_adjacent_words: 96
# "size", total_adjacent_words: 1158
# "pull", total_adjacent_words: 4315
# "wiry", total_adjacent_words: 28
# "limb", total_adjacent_words: 748
# "human", total_adjacent_words: 2963
# "youngster", total_adjacent_words: 510
# "use", total_adjacent_words: 7947
# "utmost", total_adjacent_words: 440
# "elastic", total_adjacent_words: 11
# "rascal", total_adjacent_words: 292
# "elongate", total_adjacent_words: 8
# "church", total_adjacent_words: 3601
# "window", total_adjacent_words: 6843
# "howl", total_adjacent_words: 927
# "priest", total_adjacent_words: 2006
# "face", total_adjacent_words: 10336
# "follow", total_adjacent_words: 9226
# "mass", total_adjacent_words: 698
# "spidery", total_adjacent_words: 12
# "draw", total_adjacent_words: 9650
# "upward", total_adjacent_words: 252
# "poke", total_adjacent_words: 394
# "curly", total_adjacent_words: 140
# "nose", total_adjacent_words: 2710
# "even", total_adjacent_words: 13350
# "top", total_adjacent_words: 4869
# "maid", total_adjacent_words: 2807
# "bed", total_adjacent_words: 8002
# "nearly", total_adjacent_words: 2868
# "scare", total_adjacent_words: 173
# "wit", total_adjacent_words: 725
# "cry", total_adjacent_words: 19133
# "lower", total_adjacent_words: 584
# "flee", total_adjacent_words: 1981
# "favorite", total_adjacent_words: 442
# "however", total_adjacent_words: 5869
# "foundling", total_adjacent_words: 14
# "small", total_adjacent_words: 6332
# "child", total_adjacent_words: 16578
# "pretend", total_adjacent_words: 1712
# "hungry", total_adjacent_words: 2241
# "always", total_adjacent_words: 9891
# "well", total_adjacent_words: 31507
# "wrap", total_adjacent_words: 1174
# "attract", total_adjacent_words: 441
# "attention", total_adjacent_words: 1039
# "young", total_adjacent_words: 22849
# "nursing", total_adjacent_words: 50
# "mother", total_adjacent_words: 17940
# "leave", total_adjacent_words: 24830
# "minute", total_adjacent_words: 2306
# "buy", total_adjacent_words: 3152
# "see", total_adjacent_words: 74425
# "poor", total_adjacent_words: 13854
# "little", total_adjacent_words: 54719
# "goodness", total_adjacent_words: 635
# "motherly", total_adjacent_words: 19
# "heart", total_adjacent_words: 12583
# "woman", total_adjacent_words: 22586
# "take", total_adjacent_words: 55567
# "give", total_adjacent_words: 43639
# "refreshment", total_adjacent_words: 82
# "meanwhile", total_adjacent_words: 1010
# "pat", total_adjacent_words: 293
# "back", total_adjacent_words: 30577
# "affectionately", total_adjacent_words: 77
# "croon", total_adjacent_words: 70
# "darling", total_adjacent_words: 584
# "affectionate", total_adjacent_words: 121
# "word", total_adjacent_words: 13262
# "flemish", total_adjacent_words: 149
# "nursery", total_adjacent_words: 175
# "breakfast", total_adjacent_words: 1215
# "five", total_adjacent_words: 2709
# "ten", total_adjacent_words: 2451
# "suppose", total_adjacent_words: 2047
# "infant", total_adjacent_words: 273
# "drain", total_adjacent_words: 130
# "breast", total_adjacent_words: 1549
# "cradle", total_adjacent_words: 873
# "wonder", total_adjacent_words: 4821
# "strange", total_adjacent_words: 5334
# "stomach", total_adjacent_words: 466
# "swollen", total_adjacent_words: 133
# "ball", total_adjacent_words: 1815
# "first", total_adjacent_words: 16849
# "moment", total_adjacent_words: 8500
# "show", total_adjacent_words: 8125
# "symptom", total_adjacent_words: 16
# "ravenous", total_adjacent_words: 49
# "hunger", total_adjacent_words: 1394
# "horrified", total_adjacent_words: 99
# "lay", total_adjacent_words: 7435
# "bundle", total_adjacent_words: 1005
# "jump", total_adjacent_words: 4239
# "shake", total_adjacent_words: 4231
# "swaddle", total_adjacent_words: 27
# "clothe", total_adjacent_words: 6031
# "laugh", total_adjacent_words: 7268
# "gibbering", total_adjacent_words: 4
# "school", total_adjacent_words: 476
# "stop", total_adjacent_words: 6798
# "play", total_adjacent_words: 6987
# "game", total_adjacent_words: 1526
# "turn", total_adjacent_words: 16886
# "sling", total_adjacent_words: 417
# "hat", total_adjacent_words: 1841
# "ring", total_adjacent_words: 6340
# "another", total_adjacent_words: 13565
# "head", total_adjacent_words: 23628
# "push", total_adjacent_words: 1975
# "kick", total_adjacent_words: 1108
# "wooden", total_adjacent_words: 1626
# "shoe", total_adjacent_words: 3387
# "owner", total_adjacent_words: 523
# "recover", total_adjacent_words: 1266
# "grow", total_adjacent_words: 16347
# "expert", total_adjacent_words: 34
# "eager", total_adjacent_words: 635
# "beforehand", total_adjacent_words: 190
# "urchin", total_adjacent_words: 16
# "change", total_adjacent_words: 5489
# "absent", total_adjacent_words: 373
# "right", total_adjacent_words: 8061
# "lad", total_adjacent_words: 4535
# "rush", total_adjacent_words: 4760
# "tremendous", total_adjacent_words: 429
# "fly", total_adjacent_words: 12427
# "piece", total_adjacent_words: 6750
# "pain", total_adjacent_words: 1971
# "fun", total_adjacent_words: 723
# "put", total_adjacent_words: 20384
# "iron", total_adjacent_words: 4835
# "pot", total_adjacent_words: 2335
# "limp", total_adjacent_words: 342
# "anywhere", total_adjacent_words: 581
# "fact", total_adjacent_words: 1303
# "fiendish", total_adjacent_words: 39
# "april", total_adjacent_words: 57
# "fool", total_adjacent_words: 1543
# "joke", total_adjacent_words: 594
# "pavement", total_adjacent_words: 159
# "hide", total_adjacent_words: 6960
# "brick", total_adjacent_words: 395
# "stub", total_adjacent_words: 26
# "tavern", total_adjacent_words: 355
# "join", total_adjacent_words: 1440
# "card", total_adjacent_words: 346
# "player", total_adjacent_words: 167
# "cheat", total_adjacent_words: 229
# "fight", total_adjacent_words: 4273
# "hurt", total_adjacent_words: 1043
# "heavily", total_adjacent_words: 505
# "kill", total_adjacent_words: 8319
# "town", total_adjacent_words: 4998
# "selling", total_adjacent_words: 12
# "mussel", total_adjacent_words: 67
# "housekeeper", total_adjacent_words: 182
# "shell", total_adjacent_words: 872
# "fish", total_adjacent_words: 6015
# "mouse", total_adjacent_words: 3527
# "let", total_adjacent_words: 17917
# "pass", total_adjacent_words: 12545
# "lip", total_adjacent_words: 2186
# "crawl", total_adjacent_words: 847
# "spider", total_adjacent_words: 488
# "mouth", total_adjacent_words: 4698
# "full", total_adjacent_words: 8920
# "sand", total_adjacent_words: 1335
# "housewife", total_adjacent_words: 125
# "peddler", total_adjacent_words: 170
# "rolling", total_adjacent_words: 157
# "pin", total_adjacent_words: 562
# "chair", total_adjacent_words: 1397
# "stool", total_adjacent_words: 495
# "alarm", total_adjacent_words: 551
# "fast", total_adjacent_words: 6129
# "bye", total_adjacent_words: 157
# "shrine", total_adjacent_words: 252
# "afraid", total_adjacent_words: 3399
# "sharp", total_adjacent_words: 1707
# "eye", total_adjacent_words: 19922
# "discovery", total_adjacent_words: 181
# "neighbor", total_adjacent_words: 1130
# "honor", total_adjacent_words: 1413
# "highly", total_adjacent_words: 406
# "smartness", total_adjacent_words: 29
# "saint", total_adjacent_words: 1257
# "become", total_adjacent_words: 12881
# "fashion", total_adjacent_words: 1076
# "holy", total_adjacent_words: 1969
# "front", total_adjacent_words: 3626
# "door", total_adjacent_words: 14102
# "religious", total_adjacent_words: 91
# "sell", total_adjacent_words: 2657
# "roar", total_adjacent_words: 1730
# "business", total_adjacent_words: 1636
# "build", total_adjacent_words: 3663
# "architect", total_adjacent_words: 74
# "niche", total_adjacent_words: 74
# "angle", total_adjacent_words: 59
# "especially", total_adjacent_words: 1035
# "provide", total_adjacent_words: 1076
# "thus", total_adjacent_words: 5301
# "guard", total_adjacent_words: 3632
# "double", total_adjacent_words: 520
# "prevent", total_adjacent_words: 1380
# "high", total_adjacent_words: 8765
# "low", total_adjacent_words: 3192
# "mean", total_adjacent_words: 5920
# "rid", total_adjacent_words: 1465
# "nobody", total_adjacent_words: 1955
# "specie", total_adjacent_words: 113
# "daddy", total_adjacent_words: 376
# "nowadays", total_adjacent_words: 145
# "specimen", total_adjacent_words: 75
# "say", total_adjacent_words: 121057
# "mad", total_adjacent_words: 1031
# "mischief", total_adjacent_words: 584
# "compare", total_adjacent_words: 416
# "housemaid", total_adjacent_words: 19
# "deceive", total_adjacent_words: 882
# "nuisance", total_adjacent_words: 14
# "generally", total_adjacent_words: 674
# "apply", total_adjacent_words: 392
# "flap", total_adjacent_words: 404
# "sail", total_adjacent_words: 3473
# "foolish", total_adjacent_words: 1031
# "person", total_adjacent_words: 3160
# "silly", total_adjacent_words: 520
# "may", total_adjacent_words: 14333
# "picture", total_adjacent_words: 1385
# "comic", total_adjacent_words: 49
# "valentine", total_adjacent_words: 222
# "reputation", total_adjacent_words: 212
# "fall", total_adjacent_words: 20003
# "tribe", total_adjacent_words: 599
# "represent", total_adjacent_words: 617
# "today", total_adjacent_words: 1727
# "tongue", total_adjacent_words: 2109
# "wear", total_adjacent_words: 4729
# "horse", total_adjacent_words: 20045
# "browse", total_adjacent_words: 67
# "sandy", total_adjacent_words: 202
# "field", total_adjacent_words: 4822
# "along", total_adjacent_words: 8654
# "canal", total_adjacent_words: 116
# "heath", total_adjacent_words: 273
# "country", total_adjacent_words: 8420
# "rustic", total_adjacent_words: 84
# "thinking", total_adjacent_words: 873
# "mount", total_adjacent_words: 4047
# "gallop", total_adjacent_words: 1360
# "beast", total_adjacent_words: 4880
# "forward", total_adjacent_words: 2933
# "tumble", total_adjacent_words: 921
# "ditch", total_adjacent_words: 482
# "nag", total_adjacent_words: 96
# "bound", total_adjacent_words: 911
# "grunt", total_adjacent_words: 202
# "abound", total_adjacent_words: 58
# "lift", total_adjacent_words: 3598
# "air", total_adjacent_words: 6506
# "boat", total_adjacent_words: 3330
# "mast", total_adjacent_words: 380
# "bounce", total_adjacent_words: 84
# "thump", total_adjacent_words: 346
# "level", total_adjacent_words: 391
# "bump", total_adjacent_words: 183
# "want", total_adjacent_words: 12020
# "orphan", total_adjacent_words: 361
# "middle", total_adjacent_words: 3387
# "spend", total_adjacent_words: 2907
# "life", total_adjacent_words: 12235
# "dutch", total_adjacent_words: 498
# "relic", total_adjacent_words: 73
# "rest", total_adjacent_words: 7683
# "luxemburg", total_adjacent_words: 10
# "trouble", total_adjacent_words: 4058
# "sort", total_adjacent_words: 3446
# "help", total_adjacent_words: 9184
# "advice", total_adjacent_words: 1702
# "certain", total_adjacent_words: 2864
# "year", total_adjacent_words: 13439
# "plague", total_adjacent_words: 293
# "cattle", total_adjacent_words: 1361
# "dumb", total_adjacent_words: 546
# "act", total_adjacent_words: 1269
# "brain", total_adjacent_words: 615
# "fever", total_adjacent_words: 179
# "giddy", total_adjacent_words: 107
# "stagger", total_adjacent_words: 246
# "unable", total_adjacent_words: 822
# "plough", total_adjacent_words: 650
# "cow", total_adjacent_words: 3345
# "threaten", total_adjacent_words: 1033
# "barrenness", total_adjacent_words: 11
# "fear", total_adjacent_words: 6954
# "starvation", total_adjacent_words: 183
# "distress", total_adjacent_words: 693
# "tomb", total_adjacent_words: 319
# "bishop", total_adjacent_words: 361
# "vow", total_adjacent_words: 938
# "pestilence", total_adjacent_words: 44
# "cease", total_adjacent_words: 1789
# "every", total_adjacent_words: 16629
# "pilgrimage", total_adjacent_words: 103
# "bury", total_adjacent_words: 2054
# "curious", total_adjacent_words: 1119
# "manner", total_adjacent_words: 2781
# "carry", total_adjacent_words: 13853
# "extent", total_adjacent_words: 210
# "imitate", total_adjacent_words: 139
# "dancing", total_adjacent_words: 649
# "gesture", total_adjacent_words: 188
# "odd", total_adjacent_words: 419
# "behavior", total_adjacent_words: 187
# "disorder", total_adjacent_words: 117
# "leap", total_adjacent_words: 2288
# "smitten", total_adjacent_words: 39
# "celebration", total_adjacent_words: 85
# "form", total_adjacent_words: 4300
# "processional", total_adjacent_words: 10
# "band", total_adjacent_words: 1159
# "music", total_adjacent_words: 2814
# "line", total_adjacent_words: 1361
# "thousand", total_adjacent_words: 4316
# "rich", total_adjacent_words: 6510
# "strong", total_adjacent_words: 5437
# "weak", total_adjacent_words: 1114
# "sick", total_adjacent_words: 1261
# "lead", total_adjacent_words: 8028
# "musician", total_adjacent_words: 810
# "singing", total_adjacent_words: 1280
# "start", total_adjacent_words: 4185
# "walk", total_adjacent_words: 9391
# "four", total_adjacent_words: 4829
# "abreast", total_adjacent_words: 40
# "method", total_adjacent_words: 151
# "march", total_adjacent_words: 1260
# "three", total_adjacent_words: 20666
# "backward", total_adjacent_words: 269
# "advance", total_adjacent_words: 1050
# "gradually", total_adjacent_words: 726
# "hill", total_adjacent_words: 6019
# "stand", total_adjacent_words: 20217
# "gift", total_adjacent_words: 2556
# "altar", total_adjacent_words: 539
# "dance", total_adjacent_words: 4445
# "aisle", total_adjacent_words: 57
# "porch", total_adjacent_words: 246
# "outside", total_adjacent_words: 3076
# "dancer", total_adjacent_words: 337
# "singer", total_adjacent_words: 260
# "distinct", total_adjacent_words: 98
# "route", total_adjacent_words: 153
# "mile", total_adjacent_words: 2352
# "hour", total_adjacent_words: 5143
# "require", total_adjacent_words: 878
# "whole", total_adjacent_words: 10104
# "procession", total_adjacent_words: 831
# "likely", total_adjacent_words: 710
# "nevertheless", total_adjacent_words: 687
# "try", total_adjacent_words: 10558
# "hope", total_adjacent_words: 4966
# "ache", total_adjacent_words: 349
# "hard", total_adjacent_words: 5498
# "ascent", total_adjacent_words: 58
# "sixty", total_adjacent_words: 173
# "hillside", total_adjacent_words: 332
# "hundred", total_adjacent_words: 5571
# "necessary", total_adjacent_words: 898
# "happen", total_adjacent_words: 8824
# "faint", total_adjacent_words: 1257
# "weary", total_adjacent_words: 1800
# "wayside", total_adjacent_words: 212
# "either", total_adjacent_words: 2526
# "side", total_adjacent_words: 10635
# "watch", total_adjacent_words: 6479
# "weakness", total_adjacent_words: 225
# "lose", total_adjacent_words: 8452
# "balance", total_adjacent_words: 194
# "drag", total_adjacent_words: 2128
# "quickly", total_adjacent_words: 4024
# "lest", total_adjacent_words: 1834
# "crush", total_adjacent_words: 608
# "wave", total_adjacent_words: 3781
# "oncoming", total_adjacent_words: 5
# "frenzy", total_adjacent_words: 46
# "fervor", total_adjacent_words: 5
# "excitement", total_adjacent_words: 431
# "waltz", total_adjacent_words: 122
# "absorb", total_adjacent_words: 172
# "motion", total_adjacent_words: 360
# "widow", total_adjacent_words: 1320
# "grief", total_adjacent_words: 1993
# "comfort", total_adjacent_words: 1449
# "bride", total_adjacent_words: 4352
# "month", total_adjacent_words: 2678
# "son", total_adjacent_words: 20771
# "edge", total_adjacent_words: 1958
# "pray", total_adjacent_words: 2331
# "fervently", total_adjacent_words: 62
# "fulfil", total_adjacent_words: 698
# "faithfully", total_adjacent_words: 517
# "rule", total_adjacent_words: 1455
# "scarcely", total_adjacent_words: 2260
# "half", total_adjacent_words: 5304
# "feel", total_adjacent_words: 10996
# "strength", total_adjacent_words: 3122
# "continue", total_adjacent_words: 3192
# "trample", total_adjacent_words: 353
# "death", total_adjacent_words: 6870
# "brief", total_adjacent_words: 65
# "open", total_adjacent_words: 13604
# "road", total_adjacent_words: 4774
# "distance", total_adjacent_words: 2977
# "forest", total_adjacent_words: 10701
# "loneliness", total_adjacent_words: 164
# "bear", total_adjacent_words: 11787
# "though", total_adjacent_words: 10268
# "rejoice", total_adjacent_words: 1426
# "yet", total_adjacent_words: 10543
# "overtax", total_adjacent_words: 9
# "die", total_adjacent_words: 8633
# "babe", total_adjacent_words: 431
# "garment", total_adjacent_words: 1549
# "scrape", total_adjacent_words: 451
# "clean", total_adjacent_words: 1950
# "ground", total_adjacent_words: 8663
# "write", total_adjacent_words: 1946
# "stick", total_adjacent_words: 4797
# "dirt", total_adjacent_words: 205
# "last", total_adjacent_words: 19938
# "measure", total_adjacent_words: 1092
# "ebb", total_adjacent_words: 105
# "pious", total_adjacent_words: 181
# "hermit", total_adjacent_words: 624
# "dwelling", total_adjacent_words: 764
# "hut", total_adjacent_words: 4332
# "stroll", total_adjacent_words: 301
# "wail", total_adjacent_words: 634
# "whence", total_adjacent_words: 1368
# "sound", total_adjacent_words: 6158
# "proceed", total_adjacent_words: 1353
# "dead", total_adjacent_words: 8265
# "live", total_adjacent_words: 18647
# "also", total_adjacent_words: 9535
# "meet", total_adjacent_words: 9417
# "sight", total_adjacent_words: 6577
# "lie", total_adjacent_words: 16303
# "floor", total_adjacent_words: 2800
# "doe", total_adjacent_words: 47
# "female", total_adjacent_words: 446
# "deer", total_adjacent_words: 1404
# "suckle", total_adjacent_words: 73
# "fawn", total_adjacent_words: 458
# "careful", total_adjacent_words: 914
# "anxious", total_adjacent_words: 1187
# "offspring", total_adjacent_words: 93
# "indeed", total_adjacent_words: 4649
# "far", total_adjacent_words: 15519
# "wood", total_adjacent_words: 10297
# "family", total_adjacent_words: 2735
# "different", total_adjacent_words: 2171
# "quality", total_adjacent_words: 391
# "food", total_adjacent_words: 5163
# "fondle", total_adjacent_words: 85
# "lap", total_adjacent_words: 663
# "large", total_adjacent_words: 8005
# "lustrous", total_adjacent_words: 44
# "appeal", total_adjacent_words: 180
# "wild", total_adjacent_words: 4400
# "tremble", total_adjacent_words: 2293
# "love", total_adjacent_words: 14057
# "realize", total_adjacent_words: 381
# "friend", total_adjacent_words: 6909
# "enemy", total_adjacent_words: 2672
# "hunter", total_adjacent_words: 1615
# "weapon", total_adjacent_words: 933
# "bird", total_adjacent_words: 12240
# "understand", total_adjacent_words: 2924
# "christian", total_adjacent_words: 826
# "burial", total_adjacent_words: 194
# "conscious", total_adjacent_words: 34
# "mourner", total_adjacent_words: 53
# "hastily", total_adjacent_words: 1069
# "grave", total_adjacent_words: 1741
# "plant", total_adjacent_words: 1609
# "flower", total_adjacent_words: 6020
# "accustomed", total_adjacent_words: 376
# "care", total_adjacent_words: 5812
# "rude", total_adjacent_words: 426
# "regularly", total_adjacent_words: 102
# "furnish", total_adjacent_words: 574
# "nourishment", total_adjacent_words: 72
# "weight", total_adjacent_words: 734
# "promise", total_adjacent_words: 7695
# "health", total_adjacent_words: 818
# "vigor", total_adjacent_words: 48
# "babyhood", total_adjacent_words: 69
# "behind", total_adjacent_words: 8293
# "robust", total_adjacent_words: 41
# "recall", total_adjacent_words: 353
# "skill", total_adjacent_words: 700
# "toy", total_adjacent_words: 299
# "happily", total_adjacent_words: 1730
# "bright", total_adjacent_words: 3647
# "shine", total_adjacent_words: 4544
# "attractive", total_adjacent_words: 130
# "willow", total_adjacent_words: 514
# "tree", total_adjacent_words: 18396
# "skirt", total_adjacent_words: 389
# "whistle", total_adjacent_words: 1681
# "visit", total_adjacent_words: 3082
# "travel", total_adjacent_words: 3409
# "wale", total_adjacent_words: 313
# "la", total_adjacent_words: 160
# "fay", total_adjacent_words: 34
# "agree", total_adjacent_words: 2638
# "bestow", total_adjacent_words: 880
# "mind", total_adjacent_words: 6078
# "conquer", total_adjacent_words: 810
# "story", total_adjacent_words: 8910
# "leader", total_adjacent_words: 479
# "civil", total_adjacent_words: 151
# "war", total_adjacent_words: 2234
# "troubled", total_adjacent_words: 350
# "battle", total_adjacent_words: 2163
# "hang", total_adjacent_words: 6445
# "branch", total_adjacent_words: 3715
# "afterwards", total_adjacent_words: 1261
# "statue", total_adjacent_words: 396
# "fountain", total_adjacent_words: 1595
# "rear", total_adjacent_words: 595
# "brussels", total_adjacent_words: 33
# "fully", total_adjacent_words: 389
# "fine", total_adjacent_words: 7007
# "character", total_adjacent_words: 617
# "unselfish", total_adjacent_words: 51
# "ready", total_adjacent_words: 6068
# "crusader", total_adjacent_words: 99
# "saracen", total_adjacent_words: 338
# "syria", total_adjacent_words: 38
# "win", total_adjacent_words: 2838
# "renown", total_adjacent_words: 112
# "bravery", total_adjacent_words: 233
# "turk", total_adjacent_words: 139
# "lance", total_adjacent_words: 630
# "sword", total_adjacent_words: 7537
# "axe", total_adjacent_words: 1179
# "unhurt", total_adjacent_words: 110
# "return", total_adjacent_words: 13148
# "castle", total_adjacent_words: 11640
# "tire", total_adjacent_words: 217
# "quiet", total_adjacent_words: 1838
# "sea", total_adjacent_words: 12097
# "britain", total_adjacent_words: 153
# "beautiful", total_adjacent_words: 15624
# "daughter", total_adjacent_words: 18480
# "edgar", total_adjacent_words: 173
# "king", total_adjacent_words: 51938
# "england", total_adjacent_words: 249
# "alliance", total_adjacent_words: 57
# "powerful", total_adjacent_words: 1290
# "monarch", total_adjacent_words: 682
# "charlemagne", total_adjacent_words: 335
# "recognize", total_adjacent_words: 885
# "ally", total_adjacent_words: 91
# "vassal", total_adjacent_words: 129
# "fief", total_adjacent_words: 5
# "province", total_adjacent_words: 512
# "flag", total_adjacent_words: 641
# "duke", total_adjacent_words: 818
# "tricolor", total_adjacent_words: 24
# "yellow", total_adjacent_words: 2500
# "vertical", total_adjacent_words: 10
# "difficulty", total_adjacent_words: 1397
# "overcome", total_adjacent_words: 1120
# "brave", total_adjacent_words: 3350
# "property", total_adjacent_words: 659
# "gold", total_adjacent_words: 13020
# "precious", total_adjacent_words: 2371
# "metal", total_adjacent_words: 623
# "add", total_adjacent_words: 2107
# "prosperity", total_adjacent_words: 244
# "must", total_adjacent_words: 23237
# "blood", total_adjacent_words: 3961
# "willingly", total_adjacent_words: 666
# "afterward", total_adjacent_words: 891
# "unite", total_adjacent_words: 166
# "kingdom", total_adjacent_words: 5616
# "nation", total_adjacent_words: 364
# "english", total_adjacent_words: 349
# "national", total_adjacent_words: 88
# "lovely", total_adjacent_words: 4859
# "jealous", total_adjacent_words: 792
# "marriage", total_adjacent_words: 2552
# "cast", total_adjacent_words: 2692
# "spell", total_adjacent_words: 1749
# "asking", total_adjacent_words: 47
# "slip", total_adjacent_words: 2570
# "fire", total_adjacent_words: 9911
# "brand", total_adjacent_words: 269
# "burn", total_adjacent_words: 4428
# "prolong", total_adjacent_words: 103
# "knight", total_adjacent_words: 4281
# "arthur", total_adjacent_words: 1084
# "enjoy", total_adjacent_words: 1813
# "joust", total_adjacent_words: 28
# "tournament", total_adjacent_words: 163
# "sport", total_adjacent_words: 590
# "adventure", total_adjacent_words: 1739
# "company", total_adjacent_words: 2327
# "table", total_adjacent_words: 5461
# "desire", total_adjacent_words: 3796
# "resist", total_adjacent_words: 481
# "box", total_adjacent_words: 2992
# "carefully", total_adjacent_words: 2064
# "alight", total_adjacent_words: 754
# "handsome", total_adjacent_words: 3383
# "philip", total_adjacent_words: 8
# "royal", total_adjacent_words: 4143
# "lady", total_adjacent_words: 7652
# "wish", total_adjacent_words: 9736
# "marry", total_adjacent_words: 9374
# "yield", total_adjacent_words: 627
# "occupy", total_adjacent_words: 470
# "affair", total_adjacent_words: 997
# "forgot", total_adjacent_words: 179
# "attend", total_adjacent_words: 1389
# "kindle", total_adjacent_words: 389
# "wife", total_adjacent_words: 18742
# "shut", total_adjacent_words: 2494
# "cave", total_adjacent_words: 3504
# "await", total_adjacent_words: 1147
# "forth", total_adjacent_words: 5222
# "need", total_adjacent_words: 3964
# "fame", total_adjacent_words: 522
# "myth", total_adjacent_words: 283
# "world", total_adjacent_words: 13163
# "denmark", total_adjacent_words: 68
# "italy", total_adjacent_words: 181
# "europe", total_adjacent_words: 331
# "conjurer", total_adjacent_words: 86
# "discern", total_adjacent_words: 125
# "dwell", total_adjacent_words: 1144
# "cloud", total_adjacent_words: 3453
# "vapor", total_adjacent_words: 81
# "coast", total_adjacent_words: 576
# "calabria", total_adjacent_words: 10
# "season", total_adjacent_words: 464
# "tide", total_adjacent_words: 525
# "weather", total_adjacent_words: 605
# "sky", total_adjacent_words: 4208
# "earth", total_adjacent_words: 8608
# "colossal", total_adjacent_words: 52
# "palace", total_adjacent_words: 14376
# "magnify", total_adjacent_words: 30
# "reflect", total_adjacent_words: 763
# "idea", total_adjacent_words: 2168
# "bluebeard", total_adjacent_words: 16
# "cover", total_adjacent_words: 5424
# "northern", total_adjacent_words: 532
# "chief", total_adjacent_words: 2784
# "crusty", total_adjacent_words: 5
# "wine", total_adjacent_words: 2929
# "song", total_adjacent_words: 3342
# "magician", total_adjacent_words: 2785
# "maiden", total_adjacent_words: 8261
# "custom", total_adjacent_words: 1064
# "sweet", total_adjacent_words: 3739
# "honey", total_adjacent_words: 920
# "sugary", total_adjacent_words: 7
# "crust", total_adjacent_words: 513
# "barrel", total_adjacent_words: 963
# "vessel", total_adjacent_words: 1308
# "chip", total_adjacent_words: 163
# "eat", total_adjacent_words: 15182
# "candy", total_adjacent_words: 90
# "sir", total_adjacent_words: 2111
# "nobleman", total_adjacent_words: 542
# "admit", total_adjacent_words: 495
# "voice", total_adjacent_words: 8773
# "sing", total_adjacent_words: 4984
# "invite", total_adjacent_words: 2042
# "courtesy", total_adjacent_words: 222
# "receive", total_adjacent_words: 5050
# "rumor", total_adjacent_words: 93
# "distant", total_adjacent_words: 1325
# "bring", total_adjacent_words: 20087
# "spite", total_adjacent_words: 1840
# "bad", total_adjacent_words: 5037
# "noble", total_adjacent_words: 2221
# "allow", total_adjacent_words: 3626
# "hunt", total_adjacent_words: 2621
# "stronghold", total_adjacent_words: 114
# "moreover", total_adjacent_words: 537
# "suspect", total_adjacent_words: 694
# "magic", total_adjacent_words: 4984
# "craft", total_adjacent_words: 155
# "cruelly", total_adjacent_words: 282
# "train", total_adjacent_words: 830
# "wrestling", total_adjacent_words: 71
# "spear", total_adjacent_words: 1512
# "shield", total_adjacent_words: 1049
# "husband", total_adjacent_words: 8082
# "brother", total_adjacent_words: 16474
# "tribal", total_adjacent_words: 6
# "roman", total_adjacent_words: 243
# "several", total_adjacent_words: 2906
# "beloved", total_adjacent_words: 1142
# "father", total_adjacent_words: 21506
# "sister", total_adjacent_words: 9450
# "vie", total_adjacent_words: 92
# "present", total_adjacent_words: 5505
# "ornament", total_adjacent_words: 649
# "pretty", total_adjacent_words: 5937
# "repay", total_adjacent_words: 274
# "tender", total_adjacent_words: 846
# "affection", total_adjacent_words: 440
# "unusually", total_adjacent_words: 112
# "skilled", total_adjacent_words: 185
# "horsemanship", total_adjacent_words: 20
# "brown", total_adjacent_words: 1636
# "color", total_adjacent_words: 920
# "tall", total_adjacent_words: 2391
# "slender", total_adjacent_words: 443
# "bold", total_adjacent_words: 816
# "dress", total_adjacent_words: 7546
# "hall", total_adjacent_words: 4796
# "occasion", total_adjacent_words: 1195
# "possess", total_adjacent_words: 1495
# "wardrobe", total_adjacent_words: 283
# "openly", total_adjacent_words: 107
# "offer", total_adjacent_words: 3815
# "title", total_adjacent_words: 257
# "succeed", total_adjacent_words: 2084
# "strove", total_adjacent_words: 224
# "lure", total_adjacent_words: 188
# "domain", total_adjacent_words: 185
# "determined", total_adjacent_words: 709
# "persevere", total_adjacent_words: 51
# "decline", total_adjacent_words: 251
# "secretly", total_adjacent_words: 657
# "determine", total_adjacent_words: 1713
# "evil", total_adjacent_words: 3942
# "report", total_adjacent_words: 817
# "enter", total_adjacent_words: 7175
# "steadfastly", total_adjacent_words: 59
# "warn", total_adjacent_words: 1224
# "dear", total_adjacent_words: 8462
# "beware", total_adjacent_words: 368
# "dangerous", total_adjacent_words: 602
# "ardor", total_adjacent_words: 15
# "chase", total_adjacent_words: 1729
# "surprise", total_adjacent_words: 2191
# "ask", total_adjacent_words: 22244
# "consent", total_adjacent_words: 2009
# "ballad", total_adjacent_words: 58
# "answer", total_adjacent_words: 15405
# "gy", total_adjacent_words: 4
# "en", total_adjacent_words: 445
# "reply", total_adjacent_words: 10434
# "exactly", total_adjacent_words: 1942
# "seek", total_adjacent_words: 5535
# "finally", total_adjacent_words: 1472
# "request", total_adjacent_words: 1257
# "trust", total_adjacent_words: 972
# "extricate", total_adjacent_words: 19
# "thou", total_adjacent_words: 13868
# "wilt", total_adjacent_words: 1635
# "free", total_adjacent_words: 3333
# "crown", total_adjacent_words: 2479
# "firm", total_adjacent_words: 509
# "encourage", total_adjacent_words: 291
# "purposely", total_adjacent_words: 131
# "refrain", total_adjacent_words: 186
# "bower", total_adjacent_words: 282
# "ancient", total_adjacent_words: 1344
# "room", total_adjacent_words: 9528
# "upstairs", total_adjacent_words: 473
# "main", total_adjacent_words: 242
# "stairway", total_adjacent_words: 106
# "robe", total_adjacent_words: 1924
# "chemise", total_adjacent_words: 20
# "soft", total_adjacent_words: 2964
# "silk", total_adjacent_words: 1758
# "bodice", total_adjacent_words: 62
# "richly", total_adjacent_words: 736
# "trim", total_adjacent_words: 164
# "lace", total_adjacent_words: 499
# "crimson", total_adjacent_words: 317
# "petticoat", total_adjacent_words: 274
# "stud", total_adjacent_words: 305
# "golden", total_adjacent_words: 13162
# "star", total_adjacent_words: 2741
# "neck", total_adjacent_words: 3734
# "clasp", total_adjacent_words: 660
# "string", total_adjacent_words: 1443
# "pearl", total_adjacent_words: 1819
# "coronet", total_adjacent_words: 54
# "resplendent", total_adjacent_words: 50
# "attire", total_adjacent_words: 404
# "fair", total_adjacent_words: 5036
# "gorgeously", total_adjacent_words: 83
# "array", total_adjacent_words: 331
# "queen", total_adjacent_words: 15404
# "hie", total_adjacent_words: 79
# "stable", total_adjacent_words: 2638
# "choose", total_adjacent_words: 3295
# "stall", total_adjacent_words: 486
# "fleet", total_adjacent_words: 365
# "astride", total_adjacent_words: 109
# "steed", total_adjacent_words: 1588
# "clap", total_adjacent_words: 708
# "ankle", total_adjacent_words: 167
# "direction", total_adjacent_words: 2249
# "aloud", total_adjacent_words: 1115
# "reecho", total_adjacent_words: 46
# "gladness", total_adjacent_words: 221
# "canter", total_adjacent_words: 34
# "feather", total_adjacent_words: 2683
# "bow", total_adjacent_words: 3771
# "twice", total_adjacent_words: 1421
# "clear", total_adjacent_words: 2984
# "smilingly", total_adjacent_words: 51
# "salutation", total_adjacent_words: 91
# "pleased", total_adjacent_words: 2233
# "chat", total_adjacent_words: 256
# "charming", total_adjacent_words: 1529
# "brilliant", total_adjacent_words: 550
# "conversation", total_adjacent_words: 922
# "pleasantly", total_adjacent_words: 205
# "suddenly", total_adjacent_words: 6228
# "opening", total_adjacent_words: 853
# "left", total_adjacent_words: 2000
# "behold", total_adjacent_words: 2661
# "frightful", total_adjacent_words: 699
# "reveal", total_adjacent_words: 560
# "true", total_adjacent_words: 3723
# "crossbeam", total_adjacent_words: 40
# "frame", total_adjacent_words: 423
# "sixteen", total_adjacent_words: 286
# "brutish", total_adjacent_words: 32
# "murderer", total_adjacent_words: 300
# "monster", total_adjacent_words: 2627
# "appear", total_adjacent_words: 6983
# "scowl", total_adjacent_words: 65
# "decide", total_adjacent_words: 2007
# "perfectly", total_adjacent_words: 755
# "instead", total_adjacent_words: 4081
# "piteously", total_adjacent_words: 206
# "entreat", total_adjacent_words: 842
# "spare", total_adjacent_words: 1226
# "thank", total_adjacent_words: 4684
# "choice", total_adjacent_words: 616
# "behead", total_adjacent_words: 118
# "remove", total_adjacent_words: 736
# "velvet", total_adjacent_words: 961
# "cloak", total_adjacent_words: 1407
# "doublet", total_adjacent_words: 66
# "spurt", total_adjacent_words: 107
# "sorry", total_adjacent_words: 1787
# "ruin", total_adjacent_words: 1033
# "haste", total_adjacent_words: 1638
# "aside", total_adjacent_words: 1379
# "unlace", total_adjacent_words: 32
# "coat", total_adjacent_words: 1909
# "decoration", total_adjacent_words: 57
# "busy", total_adjacent_words: 1180
# "task", total_adjacent_words: 2045
# "deftly", total_adjacent_words: 47
# "sheath", total_adjacent_words: 280
# "skilful", total_adjacent_words: 279
# "sweep", total_adjacent_words: 1733
# "blade", total_adjacent_words: 740
# "utter", total_adjacent_words: 1954
# "beseech", total_adjacent_words: 259
# "hunting", total_adjacent_words: 783
# "horn", total_adjacent_words: 2996
# "yonder", total_adjacent_words: 853
# "grain", total_adjacent_words: 1425
# "blow", total_adjacent_words: 6248
# "servant", total_adjacent_words: 5824
# "shout", total_adjacent_words: 2443
# "angry", total_adjacent_words: 3649
# "salve", total_adjacent_words: 97
# "anoint", total_adjacent_words: 229
# "prop", total_adjacent_words: 40
# "headless", total_adjacent_words: 110
# "corpse", total_adjacent_words: 852
# "still", total_adjacent_words: 15384
# "repair", total_adjacent_words: 293
# "wash", total_adjacent_words: 2403
# "spring", total_adjacent_words: 6371
# "cold", total_adjacent_words: 3634
# "roll", total_adjacent_words: 3364
# "conceal", total_adjacent_words: 1069
# "singe", total_adjacent_words: 1416
# "victory", total_adjacent_words: 592
# "green", total_adjacent_words: 5921
# "chance", total_adjacent_words: 2475
# "yes", total_adjacent_words: 2989
# "renowned", total_adjacent_words: 76
# "lord", total_adjacent_words: 5141
# "art", total_adjacent_words: 3147
# "furlong", total_adjacent_words: 22
# "news", total_adjacent_words: 2430
# "homeward", total_adjacent_words: 513
# "apron", total_adjacent_words: 493
# "stain", total_adjacent_words: 344
# "past", total_adjacent_words: 2218
# "rage", total_adjacent_words: 3168
# "angrily", total_adjacent_words: 760
# "ugly", total_adjacent_words: 2264
# "lucky", total_adjacent_words: 596
# "stiff", total_adjacent_words: 401
# "furiously", total_adjacent_words: 356
# "blast", total_adjacent_words: 494
# "exceed", total_adjacent_words: 169
# "garrison", total_adjacent_words: 57
# "warm", total_adjacent_words: 2512
# "greeting", total_adjacent_words: 409
# "forget", total_adjacent_words: 5134
# "joy", total_adjacent_words: 5286
# "welcome", total_adjacent_words: 1864
# "alive", total_adjacent_words: 2259
# "store", total_adjacent_words: 802
# "banquet", total_adjacent_words: 888
# "proper", total_adjacent_words: 1020
# "partake", total_adjacent_words: 94
# "viand", total_adjacent_words: 110
# "huge", total_adjacent_words: 3000
# "dish", total_adjacent_words: 2531
# "napkin", total_adjacent_words: 114
# "deafen", total_adjacent_words: 94
# "warrior", total_adjacent_words: 1714
# "gruesome", total_adjacent_words: 30
# "wicked", total_adjacent_words: 4011
# "irish", total_adjacent_words: 169
# "ship", total_adjacent_words: 6060
# "sod", total_adjacent_words: 194
# "hotel", total_adjacent_words: 53
# "seven", total_adjacent_words: 5461
# "patrick", total_adjacent_words: 145
# "ireland", total_adjacent_words: 880
# "snake", total_adjacent_words: 2766
# "pleasanter", total_adjacent_words: 45
# "rough", total_adjacent_words: 1208
# "island", total_adjacent_words: 3246
# "clan", total_adjacent_words: 48
# "common", total_adjacent_words: 1094
# "beauty", total_adjacent_words: 4685
# "colleen", total_adjacent_words: 6
# "warlike", total_adjacent_words: 119
# "proud", total_adjacent_words: 1584
# "ancestor", total_adjacent_words: 361
# "approve", total_adjacent_words: 224
# "plenty", total_adjacent_words: 1455
# "vine", total_adjacent_words: 616
# "wall", total_adjacent_words: 5738
# "shamrock", total_adjacent_words: 65
# "teach", total_adjacent_words: 2232
# "stem", total_adjacent_words: 337
# "symbol", total_adjacent_words: 236
# "triune", total_adjacent_words: 8
# "deity", total_adjacent_words: 153
# "worship", total_adjacent_words: 524
# "speak", total_adjacent_words: 11895
# "faithful", total_adjacent_words: 2047
# "hearing", total_adjacent_words: 289
# "loveliest", total_adjacent_words: 100
# "erin", total_adjacent_words: 420
# "neighboring", total_adjacent_words: 282
# "county", total_adjacent_words: 174
# "happy", total_adjacent_words: 5363
# "grace", total_adjacent_words: 563
# "besides", total_adjacent_words: 2086
# "greatly", total_adjacent_words: 1836
# "glory", total_adjacent_words: 747
# "prowess", total_adjacent_words: 103
# "parent", total_adjacent_words: 2241
# "propose", total_adjacent_words: 719
# "match", total_adjacent_words: 648
# "already", total_adjacent_words: 4081
# "drawback", total_adjacent_words: 1
# "ardent", total_adjacent_words: 121
# "lover", total_adjacent_words: 1391
# "pagan", total_adjacent_words: 147
# "wrong", total_adjacent_words: 1117
# "believe", total_adjacent_words: 4090
# "god", total_adjacent_words: 8537
# "sabbath", total_adjacent_words: 25
# "ruler", total_adjacent_words: 582
# "law", total_adjacent_words: 888
# "truce", total_adjacent_words: 13
# "fighting", total_adjacent_words: 259
# "nothing", total_adjacent_words: 14052
# "insist", total_adjacent_words: 920
# "gentle", total_adjacent_words: 1514
# "disposition", total_adjacent_words: 272
# "tame", total_adjacent_words: 366
# "tiger", total_adjacent_words: 1576
# "lion", total_adjacent_words: 2966
# "passion", total_adjacent_words: 610
# "grand", total_adjacent_words: 1917
# "pleasant", total_adjacent_words: 1216
# "sew", total_adjacent_words: 616
# "wedding", total_adjacent_words: 3531
# "resolve", total_adjacent_words: 2004
# "escape", total_adjacent_words: 3702
# "across", total_adjacent_words: 4389
# "captain", total_adjacent_words: 1947
# "sailor", total_adjacent_words: 925
# "tower", total_adjacent_words: 3145
# "sentinel", total_adjacent_words: 95
# "asleep", total_adjacent_words: 4686
# "dream", total_adjacent_words: 4230
# "greet", total_adjacent_words: 1348
# "smile", total_adjacent_words: 3243
# "curtsy", total_adjacent_words: 67
# "garden", total_adjacent_words: 5713
# "marguerite", total_adjacent_words: 21
# "daisy", total_adjacent_words: 180
# "white", total_adjacent_words: 11258
# "petal", total_adjacent_words: 177
# "ray", total_adjacent_words: 973
# "strip", total_adjacent_words: 679
# "centre", total_adjacent_words: 583
# "lily", total_adjacent_words: 418
# "blue", total_adjacent_words: 4672
# "wax", total_adjacent_words: 623
# "oriental", total_adjacent_words: 142
# "tulip", total_adjacent_words: 157
# "orange", total_adjacent_words: 602
# "blossom", total_adjacent_words: 925
# "hazel", total_adjacent_words: 298
# "bud", total_adjacent_words: 319
# "apple", total_adjacent_words: 3886
# "lowland", total_adjacent_words: 42
# "highland", total_adjacent_words: 178
# "east", total_adjacent_words: 1657
# "south", total_adjacent_words: 1209
# "dearly", total_adjacent_words: 751
# "thought", total_adjacent_words: 3852
# "overlook", total_adjacent_words: 272
# "lake", total_adjacent_words: 3368
# "cloudlike", total_adjacent_words: 8
# "settle", total_adjacent_words: 1295
# "radiant", total_adjacent_words: 316
# "forehead", total_adjacent_words: 1313
# "silvery", total_adjacent_words: 393
# "wand", total_adjacent_words: 1063
# "sward", total_adjacent_words: 46
# "drop", total_adjacent_words: 4546
# "curtsey", total_adjacent_words: 66
# "float", total_adjacent_words: 1901
# "soil", total_adjacent_words: 521
# "whatever", total_adjacent_words: 2420
# "hen", total_adjacent_words: 1633
# "croft", total_adjacent_words: 13
# "gather", total_adjacent_words: 3540
# "tiny", total_adjacent_words: 2320
# "chick", total_adjacent_words: 66
# "hold", total_adjacent_words: 12951
# "grasp", total_adjacent_words: 1064
# "hurry", total_adjacent_words: 3412
# "work", total_adjacent_words: 10748
# "disappear", total_adjacent_words: 3417
# "sunrise", total_adjacent_words: 705
# "barn", total_adjacent_words: 686
# "salt", total_adjacent_words: 1067
# "eastern", total_adjacent_words: 487
# "begin", total_adjacent_words: 21033
# "gray", total_adjacent_words: 1176
# "faintly", total_adjacent_words: 107
# "tomorrow", total_adjacent_words: 2685
# "command", total_adjacent_words: 3261
# "sure", total_adjacent_words: 5412
# "vanish", total_adjacent_words: 1725
# "grass", total_adjacent_words: 3304
# "breeze", total_adjacent_words: 662
# "sun", total_adjacent_words: 8582
# "bush", total_adjacent_words: 2203
# "roost", total_adjacent_words: 110
# "comfortably", total_adjacent_words: 400
# "close", total_adjacent_words: 5891
# "wing", total_adjacent_words: 3927
# "envy", total_adjacent_words: 603
# "terror", total_adjacent_words: 1859
# "awful", total_adjacent_words: 791
# "sense", total_adjacent_words: 974
# "wind", total_adjacent_words: 7379
# "arise", total_adjacent_words: 1819
# "storm", total_adjacent_words: 1834
# "drown", total_adjacent_words: 1159
# "planet", total_adjacent_words: 27
# "blink", total_adjacent_words: 182
# "peace", total_adjacent_words: 2359
# "fold", total_adjacent_words: 785
# "surely", total_adjacent_words: 1989
# "west", total_adjacent_words: 1475
# "glow", total_adjacent_words: 843
# "linger", total_adjacent_words: 353
# "next", total_adjacent_words: 10024
# "move", total_adjacent_words: 4577
# "shore", total_adjacent_words: 3265
# "rub", total_adjacent_words: 1674
# "sparkle", total_adjacent_words: 779
# "gleam", total_adjacent_words: 917
# "gain", total_adjacent_words: 1696
# ...
# "ingratiate", total_adjacent_words: 11
# "measurement", total_adjacent_words: 5
# "ascended", total_adjacent_words: 5
# "ascending", total_adjacent_words: 2
# "strung", total_adjacent_words: 15
# "lieutenant", total_adjacent_words: 24
# "perfumer", total_adjacent_words: 14
# "tasted", total_adjacent_words: 5
# "fillet", total_adjacent_words: 8
# "refulgent", total_adjacent_words: 8
# "emancipate", total_adjacent_words: 7
# "heard", total_adjacent_words: 6
# "sufficiency", total_adjacent_words: 4
# "burnouse", total_adjacent_words: 8
# "banditti", total_adjacent_words: 7
# "rendezvous", total_adjacent_words: 30
# "unbridle", total_adjacent_words: 11
# "personable", total_adjacent_words: 5
# "babas", total_adjacent_words: 125
# "reserved", total_adjacent_words: 8
# "umbrage", total_adjacent_words: 8
# "advert", total_adjacent_words: 4
# "fraternal", total_adjacent_words: 6
# "inviolable", total_adjacent_words: 8
# "efficacious", total_adjacent_words: 12
# "imaum", total_adjacent_words: 17
# "advantageously", total_adjacent_words: 6
# "suffrage", total_adjacent_words: 5
# "abortive", total_adjacent_words: 8
# "returning", total_adjacent_words: 8
# "plunderer", total_adjacent_words: 4
# "prodigiously", total_adjacent_words: 8
# "assiduity", total_adjacent_words: 5
# "straiten", total_adjacent_words: 8
# "ragout", total_adjacent_words: 8
# "assassinate", total_adjacent_words: 13
# "tabor", total_adjacent_words: 72
# "fictitious", total_adjacent_words: 7
# "unacquainted", total_adjacent_words: 8
# "endue", total_adjacent_words: 4
# "genuflexion", total_adjacent_words: 16
# "samaria", total_adjacent_words: 41
# "samer", total_adjacent_words: 22
# "sloth", total_adjacent_words: 7
# "signalise", total_adjacent_words: 15
# "indiscreet", total_adjacent_words: 13
# "foamed", total_adjacent_words: 6
# "yielding", total_adjacent_words: 8
# "partially", total_adjacent_words: 8
# "concur", total_adjacent_words: 6
# "shaped", total_adjacent_words: 6
# "weltering", total_adjacent_words: 7
# "caravanserai", total_adjacent_words: 30
# "dubious", total_adjacent_words: 8
# "repenting", total_adjacent_words: 1
# "pastil", total_adjacent_words: 8
# "voyager", total_adjacent_words: 29
# "rectify", total_adjacent_words: 11
# "dissipation", total_adjacent_words: 8
# "irregular", total_adjacent_words: 8
# "wretchedly", total_adjacent_words: 12
# "misspend", total_adjacent_words: 7
# "jointly", total_adjacent_words: 13
# "nimblest", total_adjacent_words: 4
# "sloop", total_adjacent_words: 14
# "maharaja", total_adjacent_words: 30
# "customhouse", total_adjacent_words: 4
# "probity", total_adjacent_words: 10
# "commodity", total_adjacent_words: 24
# "nutmegs", total_adjacent_words: 7
# "bountiful", total_adjacent_words: 7
# "bigness", total_adjacent_words: 11
# "exclude", total_adjacent_words: 5
# "largeness", total_adjacent_words: 14
# "shipping", total_adjacent_words: 5
# "exude", total_adjacent_words: 6
# "thicken", total_adjacent_words: 8
# "consistency", total_adjacent_words: 8
# "locust", total_adjacent_words: 8
# "recruit", total_adjacent_words: 21
# "thickness", total_adjacent_words: 29
# "distemper", total_adjacent_words: 16
# "indisposition", total_adjacent_words: 6
# "rigorous", total_adjacent_words: 8
# "interment", total_adjacent_words: 6
# "piecemeal", total_adjacent_words: 13
# "navigate", total_adjacent_words: 18
# "cocoas", total_adjacent_words: 8
# "emeralds", total_adjacent_words: 7
# "pistachio", total_adjacent_words: 4
# "rigidly", total_adjacent_words: 3
# "comport", total_adjacent_words: 14
# "suez", total_adjacent_words: 8
# "vicegerent", total_adjacent_words: 8
# "raja", total_adjacent_words: 8
# "monsoon", total_adjacent_words: 12
# "comparable", total_adjacent_words: 8
# "albania", total_adjacent_words: 8
# "degrading", total_adjacent_words: 8
# "unseaworthy", total_adjacent_words: 8
# "cropped", total_adjacent_words: 12
# "unconsolable", total_adjacent_words: 7
# "flatterer", total_adjacent_words: 14
# "beaumont", total_adjacent_words: 3
# "sonnet", total_adjacent_words: 8
# "elegy", total_adjacent_words: 8
# "madrigal", total_adjacent_words: 8
# "wilfulness", total_adjacent_words: 6
# "interference", total_adjacent_words: 8
# "taffeta", total_adjacent_words: 7
# "immortalize", total_adjacent_words: 8
# "bobbin", total_adjacent_words: 54
# "necessarily", total_adjacent_words: 8
# "beefeater", total_adjacent_words: 16
# "amorous", total_adjacent_words: 7
# "pimple", total_adjacent_words: 8
# "connected", total_adjacent_words: 8
# "almoner", total_adjacent_words: 8
# "proudest", total_adjacent_words: 8
# "pinner", total_adjacent_words: 8
# "mademoiselle", total_adjacent_words: 6
# "mousetrap", total_adjacent_words: 6
# "bedaub", total_adjacent_words: 8
# "smiling", total_adjacent_words: 13
# "charlotte", total_adjacent_words: 14
# "cornice", total_adjacent_words: 24
# "dreg", total_adjacent_words: 13
# "guiltless", total_adjacent_words: 4
# "unhooked", total_adjacent_words: 8
# "lathe", total_adjacent_words: 19
# "ninepin", total_adjacent_words: 4
# "desponding", total_adjacent_words: 13
# "melchior", total_adjacent_words: 16
# "belshazzar", total_adjacent_words: 8
# "sheepshank", total_adjacent_words: 10
# "aviary", total_adjacent_words: 4
# "pantomime", total_adjacent_words: 8
# "unbecoming", total_adjacent_words: 7
# "attorney", total_adjacent_words: 70
# "scrivener", total_adjacent_words: 3
# "comfortless", total_adjacent_words: 6
# "felicia", total_adjacent_words: 164
# "bruno", total_adjacent_words: 61
# "replant", total_adjacent_words: 4
# "deft", total_adjacent_words: 13
# "pussycat", total_adjacent_words: 4
# "fricassee", total_adjacent_words: 14
# "nectarine", total_adjacent_words: 8
# "crossest", total_adjacent_words: 7
# "prudently", total_adjacent_words: 13
# "nightshade", total_adjacent_words: 8
# "raze", total_adjacent_words: 5
# "brassbound", total_adjacent_words: 20
# "highwater", total_adjacent_words: 6
# "boxer", total_adjacent_words: 4
# "misrepresent", total_adjacent_words: 5
# "wagoner", total_adjacent_words: 13
# "savored", total_adjacent_words: 8
# "basting", total_adjacent_words: 8
# "ruminate", total_adjacent_words: 8
# "pummelling", total_adjacent_words: 8
# "naval", total_adjacent_words: 5
# "animadvert", total_adjacent_words: 7
# "providential", total_adjacent_words: 8
# "aldermen", total_adjacent_words: 8
# "stationer", total_adjacent_words: 8
# "eminent", total_adjacent_words: 8
# "mayoralty", total_adjacent_words: 6
# "sheepishly", total_adjacent_words: 4
# "unhappiest", total_adjacent_words: 4
# "jasmines", total_adjacent_words: 8
# "foxhole", total_adjacent_words: 8
# "incommode", total_adjacent_words: 15
# "bemire", total_adjacent_words: 8
# "carroty", total_adjacent_words: 4
# "roasting", total_adjacent_words: 18
# "maneuver", total_adjacent_words: 5
# "threepenny", total_adjacent_words: 7
# "blowout", total_adjacent_words: 3
# "jeeringly", total_adjacent_words: 8
# "doorknocker", total_adjacent_words: 8
# "toadstools", total_adjacent_words: 4
# "jericho", total_adjacent_words: 5
# "slaughterer", total_adjacent_words: 24
# "iniquity", total_adjacent_words: 8
# "fanny", total_adjacent_words: 6
# "laughable", total_adjacent_words: 6
# "faultfinding", total_adjacent_words: 8
# "ungratefully", total_adjacent_words: 6
# "powerlessness", total_adjacent_words: 8
# "tameness", total_adjacent_words: 8
# "extol", total_adjacent_words: 5
# "musketeer", total_adjacent_words: 8
# "appall", total_adjacent_words: 5
# "unrecognizable", total_adjacent_words: 4
# "duster", total_adjacent_words: 14
# "workroom", total_adjacent_words: 7
# "pigmy", total_adjacent_words: 21
# "bates", total_adjacent_words: 7
# "burton", total_adjacent_words: 13
# "hosier", total_adjacent_words: 4
# "bristol", total_adjacent_words: 6
# "5th", total_adjacent_words: 4
# "spyglass", total_adjacent_words: 16
# "lilliput", total_adjacent_words: 56
# "license", total_adjacent_words: 4
# "seamen", total_adjacent_words: 6
# "packthread", total_adjacent_words: 5
# "treble", total_adjacent_words: 12
# "unwillingness", total_adjacent_words: 16
# "ewe", total_adjacent_words: 33
# "sept", total_adjacent_words: 8
# "13th", total_adjacent_words: 6
# "kinder", total_adjacent_words: 18
# "roughen", total_adjacent_words: 8
# "incognito", total_adjacent_words: 8
# "samarcand", total_adjacent_words: 15
# "agreeableness", total_adjacent_words: 8
# "profuseness", total_adjacent_words: 8
# "exaggeration", total_adjacent_words: 8
# "inveigle", total_adjacent_words: 6
# "indiscreetly", total_adjacent_words: 8
# "footstool", total_adjacent_words: 18
# "mustachio", total_adjacent_words: 8
# "gaping", total_adjacent_words: 6
# "slipknot", total_adjacent_words: 8
# "leyden", total_adjacent_words: 18
# "langsyne", total_adjacent_words: 4
# "auldest", total_adjacent_words: 4
# "bonnier", total_adjacent_words: 16
# "rase", total_adjacent_words: 2
# "damosel", total_adjacent_words: 32
# "ilk", total_adjacent_words: 16
# "sharpening", total_adjacent_words: 11
# "watercourse", total_adjacent_words: 13
# "conrad", total_adjacent_words: 95
# "waddler", total_adjacent_words: 2
# "shrift", total_adjacent_words: 8
# "baser", total_adjacent_words: 8
# "overmaster", total_adjacent_words: 6
# "besmear", total_adjacent_words: 31
# "purvey", total_adjacent_words: 5
# "tended", total_adjacent_words: 8
# "licking", total_adjacent_words: 2
# "superintendence", total_adjacent_words: 14
# "thronging", total_adjacent_words: 6
# "pleasance", total_adjacent_words: 8
# "rushlight", total_adjacent_words: 8
# "uprooted", total_adjacent_words: 16
# "lentil", total_adjacent_words: 71
# "backdoor", total_adjacent_words: 20
# "fetched", total_adjacent_words: 9
# "flagrant", total_adjacent_words: 8
# "hesse", total_adjacent_words: 5
# "glanced", total_adjacent_words: 6
# "holdfast", total_adjacent_words: 1
# "shaver", total_adjacent_words: 2
# "cockloft", total_adjacent_words: 8
# "hindfoot", total_adjacent_words: 8
# "hanss", total_adjacent_words: 18
# "anticipated", total_adjacent_words: 10
# "rubbishing", total_adjacent_words: 2
# "unfurnished", total_adjacent_words: 8
# "knothole", total_adjacent_words: 12
# "snails", total_adjacent_words: 5
# "cutout", total_adjacent_words: 8
# "dandy", total_adjacent_words: 9
# "disadvantage", total_adjacent_words: 6
# "holloa", total_adjacent_words: 0
# "goliath", total_adjacent_words: 4
# "lighthearted", total_adjacent_words: 13
# "aster", total_adjacent_words: 8
# "sticking", total_adjacent_words: 12
# "epithet", total_adjacent_words: 12
# "gamecock", total_adjacent_words: 5
# "poisoned", total_adjacent_words: 3
# "begrimed", total_adjacent_words: 8
# "movingly", total_adjacent_words: 4
# "caspar", total_adjacent_words: 8
# "rumpelstiltskin", total_adjacent_words: 7
# "rational", total_adjacent_words: 5
# "walker", total_adjacent_words: 11
# "besprinkle", total_adjacent_words: 12
# "fourthly", total_adjacent_words: 7
# "riddance", total_adjacent_words: 14
# "meant", total_adjacent_words: 8
# "unmindful", total_adjacent_words: 7
# "jollier", total_adjacent_words: 4
# "fairing", total_adjacent_words: 5
# "tzar", total_adjacent_words: 778
# "sturgeon", total_adjacent_words: 44
# "warmer", total_adjacent_words: 6
# "pith", total_adjacent_words: 27
# "reciting", total_adjacent_words: 6
# "tzara", total_adjacent_words: 3
# "kopeck", total_adjacent_words: 11
# "dulcimer", total_adjacent_words: 139
# "volkhov", total_adjacent_words: 53
# "huger", total_adjacent_words: 8
# "balalaika", total_adjacent_words: 8
# "tzars", total_adjacent_words: 57
# "stiffness", total_adjacent_words: 8
# "bathhouse", total_adjacent_words: 76
# "bopeep", total_adjacent_words: 8
# "tangling", total_adjacent_words: 6
# "wetter", total_adjacent_words: 16
# "excellencys", total_adjacent_words: 2
# "dusting", total_adjacent_words: 5
# "swishing", total_adjacent_words: 7
# "beetroot", total_adjacent_words: 13
# "creaky", total_adjacent_words: 22
# "rickety", total_adjacent_words: 8
# "wanted", total_adjacent_words: 5
# "grumpily", total_adjacent_words: 4
# "hub", total_adjacent_words: 35
# "pouf", total_adjacent_words: 4
# "ivanovs", total_adjacent_words: 5
# "roach", total_adjacent_words: 17
# "dace", total_adjacent_words: 18
# "roachs", total_adjacent_words: 8
# "gilding", total_adjacent_words: 5
# "overhanging", total_adjacent_words: 4
# "troughs", total_adjacent_words: 10
# "quaver", total_adjacent_words: 25
# "padding", total_adjacent_words: 8
# "dropping", total_adjacent_words: 8
# "treeless", total_adjacent_words: 9
# "hotter", total_adjacent_words: 5
# "kindest", total_adjacent_words: 8
# "cartridge", total_adjacent_words: 10
# "sempstress", total_adjacent_words: 8
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/h1/88vswkjs65x3v7m1ytlwgpy40000gp/T/ipykernel_6506/3486194016.py", line 4, in <module>
#     store_encoding(word, 'data/fairytales_iterative_vectors.json', {'deltas': [-4, -3, -2, -1, 1, 2, 3, 4], 'bits':32})
#   File "/var/folders/h1/88vswkjs65x3v7m1ytlwgpy40000gp/T/ipykernel_6506/201905668.py", line 2, in store_encoding
#     vector = list(extract_vectors(word, **args))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/h1/88vswkjs65x3v7m1ytlwgpy40000gp/T/ipykernel_6506/4129541017.py", line -1, in extract_vectors
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#                                               ^^^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/Users/Yourui/Library/Python/3.11/lib/python/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
